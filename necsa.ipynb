# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

# %%
env = gym.make("ALE/Breakout-v5")

model = DQN("MlpPolicy", env, verbose=1, device="cpu", buffer_size = 10000, learning_starts = 1000, tensorboard_log = 'DQN')
model.learn(total_timesteps=100000, log_interval=4)
model.save("dqn_breakout")

del model # remove to demonstrate saving and loading

model = DQN.load("dqn_breakout")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to DQN\DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1240     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 240      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000231 |
# |    n_updates        | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 88       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 2324     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.43e-05 |
# |    n_updates        | 330      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 74       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 3161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 67       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 4008     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000211 |
# |    n_updates        | 751      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 63       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 4686     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000327 |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 60       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 5445     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000247 |
# |    n_updates        | 1111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 57       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 6209     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 56       |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 7032     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000184 |
# |    n_updates        | 1507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 54       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 7803     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000314 |
# |    n_updates        | 1700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 53       |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 8618     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000109 |
# |    n_updates        | 1904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.0834   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 52       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 9648     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000232 |
# |    n_updates        | 2161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 51       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 10581    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 50       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 11461    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43e-05 |
# |    n_updates        | 2615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 50       |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 12957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000381 |
# |    n_updates        | 2989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 49       |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 14109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000596 |
# |    n_updates        | 3277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 49       |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 15597    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.54e-05 |
# |    n_updates        | 3649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 48       |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 16934    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.97e-05 |
# |    n_updates        | 3983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 48       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 18230    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000175 |
# |    n_updates        | 4307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 48       |
# |    time_elapsed     | 400      |
# |    total_timesteps  | 19383    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02e-05 |
# |    n_updates        | 4595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | 1.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 48       |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 20680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.89e-05 |
# |    n_updates        | 4919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 254      |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 48       |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 22350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31e-05 |
# |    n_updates        | 5337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 47       |
# |    time_elapsed     | 504      |
# |    total_timesteps  | 24101    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 5775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 268      |
# |    ep_rew_mean      | 1.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 47       |
# |    time_elapsed     | 538      |
# |    total_timesteps  | 25719    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6e-05  |
# |    n_updates        | 6179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 47       |
# |    time_elapsed     | 571      |
# |    total_timesteps  | 27277    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000145 |
# |    n_updates        | 6569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 47       |
# |    time_elapsed     | 598      |
# |    total_timesteps  | 28529    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.4e-05  |
# |    n_updates        | 6882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 47       |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 30271    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.32e-05 |
# |    n_updates        | 7317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | 1.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 47       |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 32063    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.08e-06 |
# |    n_updates        | 7765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 1.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 47       |
# |    time_elapsed     | 716      |
# |    total_timesteps  | 33966    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21e-05 |
# |    n_updates        | 8241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 311      |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 47       |
# |    time_elapsed     | 742      |
# |    total_timesteps  | 35141    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000138 |
# |    n_updates        | 8535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 323      |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 47       |
# |    time_elapsed     | 783      |
# |    total_timesteps  | 37006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.22e-05 |
# |    n_updates        | 9001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 329      |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 47       |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 38380    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000209 |
# |    n_updates        | 9344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 334      |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 46       |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 39629    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08e-05 |
# |    n_updates        | 9657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 339      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 46       |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 40940    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21e-05 |
# |    n_updates        | 9984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 346      |
# |    ep_rew_mean      | 2.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 46       |
# |    time_elapsed     | 908      |
# |    total_timesteps  | 42362    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00049  |
# |    n_updates        | 10340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 347      |
# |    ep_rew_mean      | 2.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 46       |
# |    time_elapsed     | 931      |
# |    total_timesteps  | 43361    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-05 |
# |    n_updates        | 10590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 350      |
# |    ep_rew_mean      | 2.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 46       |
# |    time_elapsed     | 959      |
# |    total_timesteps  | 44658    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.87e-05 |
# |    n_updates        | 10914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 354      |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 46       |
# |    time_elapsed     | 986      |
# |    total_timesteps  | 45973    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 11243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 361      |
# |    ep_rew_mean      | 2.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 46       |
# |    time_elapsed     | 1024     |
# |    total_timesteps  | 47586    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00015  |
# |    n_updates        | 11646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 360      |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 46       |
# |    time_elapsed     | 1054     |
# |    total_timesteps  | 48953    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.25e-05 |
# |    n_updates        | 11988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 363      |
# |    ep_rew_mean      | 2.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 46       |
# |    time_elapsed     | 1085     |
# |    total_timesteps  | 50382    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.29e-05 |
# |    n_updates        | 12345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 361      |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 46       |
# |    time_elapsed     | 1113     |
# |    total_timesteps  | 51674    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.51e-05 |
# |    n_updates        | 12668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 358      |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 46       |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 52693    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000104 |
# |    n_updates        | 12923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 358      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 46       |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 54007    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000254 |
# |    n_updates        | 13251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 366      |
# |    ep_rew_mean      | 1.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 46       |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 56019    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000347 |
# |    n_updates        | 13754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 2.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 46       |
# |    time_elapsed     | 1262     |
# |    total_timesteps  | 58465    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.94e-05 |
# |    n_updates        | 14366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 2.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 46       |
# |    time_elapsed     | 1296     |
# |    total_timesteps  | 60114    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.09e-05 |
# |    n_updates        | 14778    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 46       |
# |    time_elapsed     | 1333     |
# |    total_timesteps  | 61904    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.25e-05 |
# |    n_updates        | 15225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 2.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 46       |
# |    time_elapsed     | 1368     |
# |    total_timesteps  | 63534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58e-05 |
# |    n_updates        | 15633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 381      |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 46       |
# |    time_elapsed     | 1406     |
# |    total_timesteps  | 65375    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 16093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 383      |
# |    ep_rew_mean      | 2.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 46       |
# |    time_elapsed     | 1439     |
# |    total_timesteps  | 66800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 16449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 2.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 46       |
# |    time_elapsed     | 1497     |
# |    total_timesteps  | 69315    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.4e-05  |
# |    n_updates        | 17078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 388      |
# |    ep_rew_mean      | 2.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 46       |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 70842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.69e-05 |
# |    n_updates        | 17460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 387      |
# |    ep_rew_mean      | 2.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 46       |
# |    time_elapsed     | 1569     |
# |    total_timesteps  | 72670    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.05e-05 |
# |    n_updates        | 17917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 392      |
# |    ep_rew_mean      | 2.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 46       |
# |    time_elapsed     | 1604     |
# |    total_timesteps  | 74376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 18343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 386      |
# |    ep_rew_mean      | 2.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 46       |
# |    time_elapsed     | 1631     |
# |    total_timesteps  | 75629    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.83e-05 |
# |    n_updates        | 18657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 387      |
# |    ep_rew_mean      | 2.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 46       |
# |    time_elapsed     | 1661     |
# |    total_timesteps  | 77097    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 19024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 389      |
# |    ep_rew_mean      | 2.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 46       |
# |    time_elapsed     | 1691     |
# |    total_timesteps  | 78483    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.41e-05 |
# |    n_updates        | 19370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 389      |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 46       |
# |    time_elapsed     | 1719     |
# |    total_timesteps  | 79832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 19707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 2.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 46       |
# |    time_elapsed     | 1752     |
# |    total_timesteps  | 81398    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 20099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 392      |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 46       |
# |    time_elapsed     | 1777     |
# |    total_timesteps  | 82595    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000246 |
# |    n_updates        | 20398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 400      |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 46       |
# |    time_elapsed     | 1818     |
# |    total_timesteps  | 84608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000573 |
# |    n_updates        | 20901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 407      |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 46       |
# |    time_elapsed     | 1860     |
# |    total_timesteps  | 86660    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 21414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 407      |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 46       |
# |    time_elapsed     | 1894     |
# |    total_timesteps  | 88281    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00021  |
# |    n_updates        | 21820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 409      |
# |    ep_rew_mean      | 1.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 46       |
# |    time_elapsed     | 1926     |
# |    total_timesteps  | 89854    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.71e-05 |
# |    n_updates        | 22213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 46       |
# |    time_elapsed     | 1967     |
# |    total_timesteps  | 91802    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.7e-05  |
# |    n_updates        | 22700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 1.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 46       |
# |    time_elapsed     | 1995     |
# |    total_timesteps  | 93159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00033  |
# |    n_updates        | 23039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 1.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 46       |
# |    time_elapsed     | 2026     |
# |    total_timesteps  | 94653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.46e-05 |
# |    n_updates        | 23413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 46       |
# |    time_elapsed     | 2061     |
# |    total_timesteps  | 96302    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.85e-05 |
# |    n_updates        | 23825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 46       |
# |    time_elapsed     | 2095     |
# |    total_timesteps  | 97848    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000331 |
# |    n_updates        | 24211    |
# ----------------------------------
