# %%
import utils
import environment 
import copy
utils.seed_all(seed = 0)

# %%
# test env
# test epsilons
# not mem = {0.1:(255,17.78),  0.15:(268,15.40),  0.2:(278,17.36), 0.25:(241,23), 0.3:(255,17.77) ,0.35:(240,16.89), 
#            0.4:(247,15.23),  0.45: (245, 15.00), 0.5: (215, 15.84), 0.55: (200, 15.69), 0.6: (190, 20.20), 0.65: (180, 25.72),
#            0.70: (150, 28.67), 0.75: (155, 24.45), 0.8: (135, 24.11), 0.85: (145, 22.94), 0.9: (145, 20.35), 0.95: (135, 22.41), 1: (95, 24.23)}
           
###
#mem = { 0.1: (269, 20.19), 0.15: (255, 15.36), 0.2: (250, 21.61), 0.25: (241, 19.97), 0.3: (258, 17.84), 0.35: (233, 20.12), 
#        0.4: (249, 12.01), 0.45: (230, 12.01), 0.5: (219, 14.206), 0.55: (206, 14.15), 0.6: (195, 19.72), 0.65: (186, 24.03), 
#        0.70: (155, 27.36), 0.75: (159, 23.19), 0.8: (139, 22.19), 0.85: (152, 22.09), 0.9: (150, 19.88), 0.95: (140, 21), 1: (100, 23.35) }


duration = 300
lanes = ['F', 'L', 'R']
directions = ['E', 'N', 'W', 'S']
A = [(['E', 'W'], ['F']), (['E', 'W'], ['L']), 
    (['N', 'S'], ['F']), (['N', 'S'], ['L']), 
    (['E'], ['F', 'L']), (['W'], ['F', 'L']), 
    (['N'], ['F', 'L']), (['S'], ['F', 'L'])]
vehicle_parameters = {'duration': duration, 'min_speed': 2.22, 'max_speed': 13.33, 
                      'lanes': lanes, 'arrival_rates': {'E': 5/60, 'N': 5/60, 'W': 10/60, 'S': 7/60}}
intersection_parameters = {'duration': duration, 'action_duration': 10, 
                           'Lanes': lanes, 'Directions': directions,'A':A, 
                           'gamma': 0.95, 'alpha': 0.1, 'espilon': 0.1, 'is_mem_based':False, 'short_term_memory_size':10,
                           'is_dynamic_action_duration': False, 'dynamic_action_duration': 4,  'epsilon_test_not_mem':0.4, 'epsilon_test_mem':0.6,
                           'reward_function': utils.calculate_reward_default, 'n_vehicle_leaving_per_lane': 1}
length = 60
graph_structure = {  'in0': (1, [('0', 0, 'E')]),
                     'in10': (1, [('0', 0, 'S')]),
                    '0': (3, [('1', length, 'S'), ('in0', 0, 'W'),('in10', 0, 'N')]), 
                    'in1': (1, [('1', 0, 'E')]), 
                    'in2': (1, [('1', 0, 'W')]),
                    '1': (4, [('2', length, 'S'), ('0', length, 'N'), ('in1', 0, 'W'), ('in2', 0, 'E')]),
                    '2': (3, [('1', length, 'N'), ('3', length, 'S'), ('in3', 0, 'W')]),
                    '3': (3, [('2', length, 'N'), ('5', length, 'S'), ('4', length, 'E')]),
                    '4': (3, [('3', length, 'W'), ('in4', 0, 'N'), ('9', length, 'E')]),
                    '5': (3, [('3', length, 'N'), ('in5', 0, 'W'), ('6', length, 'E'), ('in6', 0, 'S')]),
                    '6': (3, [('5', length, 'W'), ('7', length, 'S'), ('10', length, 'E')]),
                    '7': (3, [('6', length, 'N'), ('8', length, 'E'), ('in11', 0, 'S')]),
                    '8': (4, [('7', length, 'W'), ('10', length, 'N'), ('in7', 0, 'S'), ('in9', 0, 'E')]),
                    '9': (3, [('10', length, 'S'), ('4', length, 'W'), ('in12', 0, 'N')]),
                    '10': (4, [('in13', 0, 'E'), ('6', 2*length, 'W'), ('9', length, 'N'), ('8', length, 'S')]),
                    'in3': (1, [('2', 0, 'E')]),
                    'in4': (1, [('4', 0, 'S')]),
                    'in5': (1, [('5', 0, 'E')]),
                    'in6': (1, [('5', 0, 'N')]),
                    'in7': (1, [('8', 0, 'N')]),
                    'in9': (1, [('8', 0, 'W')]), 
                    'in11': (1, [('7', 0, 'N')]),
                    'in12': (1, [('9', 0, 'S')]),
                    'in13': (1, [('10', 0, 'W')])}


# Assuming `length` is defined somewhere above

graph_structure_params = {'graph_structure': graph_structure, 'length': 60}
# graph_structure_params = {'rows': 2, 'cols': 2, 'length': 60}
communcation_parameters = {'A': A, 'duration': duration, 'mu': 0.0, 'sigma': 1.0, 'tau': 0.0, 'Directions': directions}
               

env_SARSA = environment.Env(duration=duration, update_type= 'partial', comm_based = False, graph_structure_parameters=graph_structure_params, 
          vehicle_parameters=vehicle_parameters, intersection_parameters=intersection_parameters,
          communication_parameters=communcation_parameters, A=A, directions=directions, lanes=lanes)
env_SARSA.graph.draw_graph_2()

# %%
env_SARSA.SARSA_run(n_episodes=1)
env_SARSA.plot_env()
# Out:
# Images combined and saved as 'plots/not_memory_based/combined/Intersection0.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection1.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection2.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection3.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection5.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection4.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection9.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection6.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection7.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection10.png'
# Images combined and saved as 'plots/not_memory_based/combined/Intersection8.png'

# %%
test_graph, test_vehicles = env_SARSA.generate_test_structures(graph_structure_parameters=graph_structure_params, 
                                                               vehicle_parameters=vehicle_parameters, 
                                                               intersection_parameters=intersection_parameters)

# %%
test_graph_mem = copy.deepcopy(test_graph)
test_graph_mem = env_SARSA.copy_q_table(from_graph=test_graph, to_graph=test_graph_mem)
test_vehicles_mem= test_vehicles.copy(new_graph=test_graph_mem)

# %%
eps=0.15
for node in test_graph.nodes.values():
    node.intersection.epsilon_test_not_mem=eps
env_SARSA.test(test_graph=test_graph, test_vehicles=test_vehicles, update_epoch = 25)
# env_SARSA.plot_env()
env_SARSA.display_congestion_metric()
# Out:
# W: total average weight time per lane: 14.99828431446527s
# average weight time per node in s (nan means no cars arrived):
#  {'0': 16.915767074777058, '1': 15.848632357644524, '2': 15.217491473474777, '3': 15.216510950134117, '5': 15.868144615260892, '4': 12.11473540012415, '9': 11.009959108123235, '6': 14.383635123321906, '7': 14.498593744491995, '10': 12.85758283931969, '8': 15.29931910133978}
# Total arriving cars: 268

# %%
eps = 0.15
test_graph.set_memory_based(is_mem_based=True)
for node in test_graph.nodes.values():
    node.intersection.epsilon_test_mem=eps
env_SARSA.test(test_graph=test_graph, test_vehicles=test_vehicles, update_epoch = 25)
# env_SARSA.plot_env()
env_SARSA.display_congestion_metric()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 eps = 0.15
# ----> 2 test_graph.set_memory_based(is_mem_based=True)
#       3 for node in test_graph.nodes.values():
#       4     node.intersection.epsilon_test_mem=eps
#
# NameError: name 'test_graph' is not defined

# %%
#np.load('metrics/run_2_2/total_clearance_2_2_mem_False_comm_False.npy')

# %%
# with open('metrics/run_2_2/node_clearance_2_2_mem_False_comm_False.pickle', 'rb') as f:
#     a = pickle.load(f)
# a
